# %% [markdown]
# # Predicción de Ataque Cardíaco usando Redes Bayesianas
#
# Este proyecto demuestra el método de Eliminación de Variables para inferencia exacta en Redes Bayesianas, aplicado a predecir la probabilidad de sufrir un ataque cardíaco basado en factores de riesgo.
#
# ## Tabla de Contenidos
# 1. [Setup](#1-setup)
# 2. [Marco Teórico](#2-marco-teórico)
# 3. [Definición de la Red](#3-definición-de-la-red)
# 4. [Inferencia Manual](#4-inferencia-manual)
# 5. [Verificación con pgmpy](#5-verificación-con-pgmpy)
# 6. [Conclusiones](#6-conclusiones)

# %% [markdown]
# ## 1. Setup

# %%
"""Setup: Importar librerías y configurar el entorno."""

# Librerías de terceros
# Suprimir warnings para una salida más limpia
import warnings

from pgmpy.factors.discrete import TabularCPD
from pgmpy.inference import VariableElimination
from pgmpy.models import DiscreteBayesianNetwork

warnings.filterwarnings('ignore')

# Constantes - Estados de las variables
ESTADO_VERDADERO = "V"  # Verdadero/Sí
ESTADO_FALSO = "F"      # Falso/No

print("Setup completado.")

# %% [markdown]
# ## 2. Marco Teórico
#
# ### 2.1 Método de Eliminación de Variables
#
# La Eliminación de Variables es un algoritmo de **inferencia exacta** para modelos gráficos probabilísticos (PGM), como las Redes Bayesianas. Calcula probabilidades condicionales eliminando sistemáticamente variables ocultas mediante marginalización.
#
# #### Conceptos Clave
#
# **Factores**: La estructura de datos fundamental en Eliminación de Variables. Un factor representa una distribución de probabilidad sobre un conjunto de variables. Se definen dos operaciones sobre los factores:
#
# 1. **Producto de Factores**: Combina dos factores (similar a JOIN en bases de datos)
# 2. **Marginalización de Factor**: Suma sobre una variable de un factor
#
# **Complejidad**: Encontrar el orden óptimo de eliminación es NP-HARD. Heurísticas comunes incluyen:
# - **Min-neighbors**: Eliminar variable con menos variables dependientes
# - **Min-weight**: Minimizar producto de cardinalidades de variables dependientes
# - **Min-fill**: Minimizar aristas añadidas al grafo
#
# #### Notación
#
# | Símbolo | Significado |
# |---------|-------------|
# | $f_X(X)$ | Factor de variable X (X es desconocida) |
# | $f_X$ | Factor de variable X conocida (constante) |
# | $f_{XY}(X,Y)$ | Producto de factores X e Y |
# | $f_{\bar{X}}(Y)$ | Factor después de marginalizar X |
#
# **Referencia**: [Stanford CS228 - Variable Elimination](https://ermongroup.github.io/cs228-notes/inference/ve/)

# %% [markdown]
# ## 3. Definición de la Red
#
# ### 3.1 Descripción del Problema
#
# Modelamos la probabilidad de tener un ataque cardíaco antes de los 70 años usando una Red Bayesiana con las siguientes variables:
#
# | Variable | Símbolo | Descripción | Estados |
# |----------|---------|-------------|---------|
# | Fumador | F | El paciente es fumador | V (Verdadero), F (Falso) |
# | Ejercicio | E | El paciente hace ejercicio regularmente | V (Verdadero), F (Falso) |
# | Presión Alta | P | El paciente tiene hipertensión | A (Alta), B (Baja/Normal) |
# | Colesterol Alto | C | El paciente tiene colesterol alto | A (Alto), B (Bajo/Normal) |
# | Ataque Cardíaco | A | El paciente sufre un ataque cardíaco | A (Sí), B (No) |
#
# ### 3.2 Estructura de la Red
#
# ```
#     F       E
#      \     /|
#       \   / |
#        \ /  |
#         P   C
#         |
#         A
# ```
#
# **Dependencias:**
# - P (Presión) depende de F (Fumador) y E (Ejercicio)
# - C (Colesterol) depende de E (Ejercicio)
# - A (Ataque) depende de P (Presión)
#
# ### 3.3 Tablas de Probabilidad Condicional
#
# **P(F) - Probabilidad de ser fumador:**
#
# | F | P(F) |
# |---|------|
# | V | 0.15 |
# | F | 0.85 |
#
# **P(E) - Probabilidad de hacer ejercicio:**
#
# | E | P(E) |
# |---|------|
# | V | 0.40 |
# | F | 0.60 |
#
# **P(P|F,E) - Probabilidad de presión alta:**
#
# | F | E | P(P=A) | P(P=B) |
# |---|---|--------|--------|
# | V | V | 0.45 | 0.55 |
# | V | F | 0.95 | 0.05 |
# | F | V | 0.05 | 0.95 |
# | F | F | 0.55 | 0.45 |
#
# **P(C|E) - Probabilidad de colesterol alto:**
#
# | E | P(C=A) | P(C=B) |
# |---|--------|--------|
# | V | 0.40 | 0.60 |
# | F | 0.80 | 0.20 |
#
# **P(A|P) - Probabilidad de ataque cardíaco:**
#
# | P | P(A=A) | P(A=B) |
# |---|--------|--------|
# | A | 0.75 | 0.25 |
# | B | 0.05 | 0.95 |

# %% [markdown]
# ## 4. Inferencia Manual
#
# Aplicamos el método de Eliminación de Variables manualmente para responder tres consultas sobre la red.
#
# ### 4.1 Consulta A: P(A | F=V)
#
# **Pregunta**: ¿Cuál es la probabilidad de un ataque cardíaco dado que el paciente es fumador?
#
# $$P(A | F=V) = \sum_P \sum_E \sum_C P(F=V) \cdot P(E) \cdot P(P|F=V,E) \cdot P(C|E) \cdot P(A|P)$$
#
# **Paso 1**: Definir factores iniciales
# - $f_A(A,P) = P(A|P)$
# - $f_P(P,E) = P(P|F=V,E)$
# - $f_E(E) = P(E)$
# - $f_C(C,E) = P(C|E)$
#
# **Paso 2**: Eliminar C (marginalizar)
#
# $f_{\bar{C}}(E) = \sum_C f_C(C,E) = 1$ para todo E
#
# **Paso 3**: Combinar y eliminar E
#
# $f_{P\bar{C}E}(P,E) = f_P(P,E) \times f_E(E)$
#
# | P | E | Prob |
# |---|---|------|
# | A | V | 0.45 × 0.4 = 0.18 |
# | A | F | 0.95 × 0.6 = 0.57 |
# | B | V | 0.55 × 0.4 = 0.22 |
# | B | F | 0.05 × 0.6 = 0.03 |
#
# $f_{P\bar{CE}}(P) = \sum_E f_{P\bar{C}E}(P,E)$
#
# | P | Prob |
# |---|------|
# | A | 0.18 + 0.57 = 0.75 |
# | B | 0.22 + 0.03 = 0.25 |
#
# **Paso 4**: Combinar con $f_A$ y eliminar P
#
# $f_{\bar{PCE}A}(A) = \sum_P f_A(A,P) \times f_{P\bar{CE}}(P)$
#
# | A | Prob |
# |---|------|
# | A | 0.75 × 0.75 + 0.05 × 0.25 = **0.575** |
# | B | 0.25 × 0.75 + 0.95 × 0.25 = 0.425 |
#
# #### Resultado
# **La probabilidad de ataque cardíaco para un fumador es 57.5%**

# %% [markdown]
# ### 4.2 Consulta B: P(P | A=A)
#
# **Pregunta**: ¿Cuál es la probabilidad de presión alta dado que el paciente tuvo un ataque cardíaco?
#
# $$P(P | A=A) = \frac{P(P, A=A)}{P(A=A)}$$
#
# Siguiendo el mismo procedimiento de Eliminación de Variables:
#
# **Después de marginalización y normalización:**
#
# | P | Prob (sin normalizar) | Prob (normalizada) |
# |---|----------------------|--------------------|
# | A | 0.3075 | **0.9125** |
# | B | 0.0295 | 0.0875 |
#
# #### Resultado
# **La probabilidad de presión alta dado un ataque cardíaco es 91.25%**

# %% [markdown]
# ### 4.3 Consulta C: P(A | F=V, C=A)
#
# **Pregunta**: ¿Cuál es la probabilidad de ataque cardíaco dado que el paciente es fumador Y tiene colesterol alto?
#
# $$P(A | F=V, C=A) = \sum_P \sum_E P(F=V) \cdot P(E) \cdot P(P|F=V,E) \cdot P(C=A|E) \cdot P(A|P)$$
#
# **Después de marginalización y normalización:**
#
# | A | Prob (sin normalizar) | Prob (normalizada) |
# |---|----------------------|--------------------|
# | A | 0.4016 | **0.6275** |
# | B | 0.2384 | 0.3725 |
#
# #### Resultado
# **La probabilidad de ataque cardíaco para un fumador con colesterol alto es 62.75%**

# %% [markdown]
# ## 5. Verificación con pgmpy
#
# Verificamos nuestros cálculos manuales usando la librería `pgmpy`.

# %%
def construir_red_ataque_cardiaco() -> DiscreteBayesianNetwork:
    """Construye la Red Bayesiana para predicción de ataque cardíaco.

    Returns:
        DiscreteBayesianNetwork: Red configurada con todas las CPDs.
    """
    # Definir estructura de la red
    red = DiscreteBayesianNetwork([
        ("F", "P"),  # Fumador -> Presión
        ("E", "P"),  # Ejercicio -> Presión
        ("E", "C"),  # Ejercicio -> Colesterol
        ("P", "A")   # Presión -> Ataque
    ])

    # Definir nombres de estados para claridad
    estados = {
        "F": [ESTADO_VERDADERO, ESTADO_FALSO],
        "E": [ESTADO_VERDADERO, ESTADO_FALSO],
        "P": ["A", "B"],
        "C": ["A", "B"],
        "A": ["A", "B"]
    }

    # P(F) - Probabilidad a priori de ser fumador
    cpd_fumador = TabularCPD(
        variable="F",
        variable_card=2,
        values=[[0.15], [0.85]],
        state_names={"F": estados["F"]}
    )

    # P(E) - Probabilidad a priori de hacer ejercicio
    cpd_ejercicio = TabularCPD(
        variable="E",
        variable_card=2,
        values=[[0.4], [0.6]],
        state_names={"E": estados["E"]}
    )

    # P(P|F,E) - Presión dado estado de fumador y ejercicio
    cpd_presion = TabularCPD(
        variable="P",
        variable_card=2,
        values=[
            [0.45, 0.95, 0.05, 0.55],  # P(P=A|...)
            [0.55, 0.05, 0.95, 0.45]   # P(P=B|...)
        ],
        evidence=["F", "E"],
        evidence_card=[2, 2],
        state_names={"P": estados["P"], "F": estados["F"], "E": estados["E"]}
    )

    # P(C|E) - Colesterol dado estado de ejercicio
    cpd_colesterol = TabularCPD(
        variable="C",
        variable_card=2,
        values=[
            [0.4, 0.8],  # P(C=A|...)
            [0.6, 0.2]   # P(C=B|...)
        ],
        evidence=["E"],
        evidence_card=[2],
        state_names={"C": estados["C"], "E": estados["E"]}
    )

    # P(A|P) - Ataque cardíaco dado presión
    cpd_ataque = TabularCPD(
        variable="A",
        variable_card=2,
        values=[
            [0.75, 0.05],  # P(A=A|...)
            [0.25, 0.95]   # P(A=B|...)
        ],
        evidence=["P"],
        evidence_card=[2],
        state_names={"A": estados["A"], "P": estados["P"]}
    )

    # Añadir CPDs a la red
    red.add_cpds(
        cpd_fumador,
        cpd_ejercicio,
        cpd_presion,
        cpd_colesterol,
        cpd_ataque
    )

    return red

# %%
# Construir red y crear motor de inferencia
red_cardiaca = construir_red_ataque_cardiaco()
inferencia = VariableElimination(red_cardiaca)

print("Validación de la red:", red_cardiaca.check_model())

# %% [markdown]
# ### 5.1 Verificar Consulta A: P(A | F=V)

# %%
# Consulta A: P(A | F=V) - Probabilidad de ataque para fumadores
resultado_a = inferencia.query(["A"], evidence={"F": ESTADO_VERDADERO})
print("Consulta A: P(A | Fumador=Verdadero)")
print(resultado_a)
print("\nCálculo manual: 0.575")
print(f"Resultado pgmpy: {resultado_a.values[0]:.4f}")
print(f"Coincide: {abs(resultado_a.values[0] - 0.575) < 0.001}")

# %% [markdown]
# ### 5.2 Verificar Consulta B: P(P | A=A)

# %%
# Consulta B: P(P | A=A) - Probabilidad de presión alta dado ataque
resultado_b = inferencia.query(["P"], evidence={"A": "A"})
print("Consulta B: P(P | Ataque=Sí)")
print(resultado_b)
print("\nCálculo manual: 0.9125")
print(f"Resultado pgmpy: {resultado_b.values[0]:.4f}")
print(f"Coincide: {abs(resultado_b.values[0] - 0.9125) < 0.001}")

# %% [markdown]
# ### 5.3 Verificar Consulta C: P(A | F=V, C=A)

# %%
# Consulta C: P(A | F=V, C=A) - Ataque para fumadores con colesterol alto
resultado_c = inferencia.query(["A"], evidence={"F": ESTADO_VERDADERO, "C": "A"})
print("Consulta C: P(A | Fumador=Verdadero, Colesterol=Alto)")
print(resultado_c)
print("\nCálculo manual: 0.6275")
print(f"Resultado pgmpy: {resultado_c.values[0]:.4f}")
print(f"Coincide: {abs(resultado_c.values[0] - 0.6275) < 0.001}")

# %% [markdown]
# ## 6. Conclusiones
#
# ### Hallazgos Principales
#
# 1. **Riesgo del Fumador**: La probabilidad de ataque cardíaco para un fumador es **57.5%**, significativamente mayor que la línea base.
#
# 2. **Factores de Riesgo Combinados**: Cuando un fumador también tiene colesterol alto, la probabilidad aumenta a **62.75%**.
#
# 3. **Asociación con Presión Arterial**: Dado que ha ocurrido un ataque cardíaco, hay un **91.25%** de probabilidad de que el paciente tuviera presión alta.
#
# 4. **Validación del Método**: Los cálculos manuales usando Eliminación de Variables coincidieron exactamente con los resultados de la librería pgmpy, validando nuestra implementación.
#
# ### Perspectivas Técnicas
#
# - El método de Eliminación de Variables calcula eficientemente probabilidades exactas eliminando variables una a la vez.
# - Encontrar el orden óptimo de eliminación es NP-HARD; heurísticas como min-neighbors son esenciales para aplicaciones prácticas.
# - Las Redes Bayesianas proporcionan modelos probabilísticos interpretables que pueden capturar dependencias condicionales complejas.
